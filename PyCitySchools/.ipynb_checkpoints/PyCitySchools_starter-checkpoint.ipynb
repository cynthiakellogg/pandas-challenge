# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
school_by_school = school_data_complete.set_index('school_name')
school_by_school
# Out:
#                     Student ID       student_name gender grade  reading_score  \
# school_name
# Huang High School            0       Paul Bradley      M   9th             66
# Huang High School            1       Victor Smith      M  12th             94
# Huang High School            2    Kevin Rodriguez      M  12th             90
# Huang High School            3  Dr. Richard Scott      M  12th             67
# Huang High School            4         Bonnie Ray      F   9th             97
# ...                        ...                ...    ...   ...            ...
# Thomas High School       39165       Donna Howard      F  12th             99
# Thomas High School       39166          Dawn Bell      F  10th             95
# Thomas High School       39167     Rebecca Tanner      F   9th             73
# Thomas High School       39168       Desiree Kidd      F  10th             99
# Thomas High School       39169    Carolyn Jackson      F  11th             95
#
#                     math_score  School ID      type  size   budget
# school_name
# Huang High School           79          0  District  2917  1910635
# Huang High School           61          0  District  2917  1910635
# Huang High School           60          0  District  2917  1910635
# Huang High School           58          0  District  2917  1910635
# Huang High School           84          0  District  2917  1910635
# ...                        ...        ...       ...   ...      ...
# Thomas High School          90         14   Charter  1635  1043130
# Thomas High School          70         14   Charter  1635  1043130
# Thomas High School          84         14   Charter  1635  1043130
# Thomas High School          90         14   Charter  1635  1043130
# Thomas High School          75         14   Charter  1635  1043130
#
# [39170 rows x 10 columns]

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
school_data_complete.columns
# Out:
# Index(['Student ID', 'student_name', 'gender', 'grade', 'school_name',
#        'reading_score', 'math_score', 'School ID', 'type', 'size', 'budget'],
#       dtype='object')

# %%
organized_df = school_data_complete[['student_name', 'grade', 'school_name',
       'reading_score', 'math_score', 'type', 'size', 'budget']]
organized_df.head()
# Out:
#         student_name grade        school_name  reading_score  math_score  \
# 0       Paul Bradley   9th  Huang High School             66          79
# 1       Victor Smith  12th  Huang High School             94          61
# 2    Kevin Rodriguez  12th  Huang High School             90          60
# 3  Dr. Richard Scott  12th  Huang High School             67          58
# 4         Bonnie Ray   9th  Huang High School             97          84
#
#        type  size   budget
# 0  District  2917  1910635
# 1  District  2917  1910635
# 2  District  2917  1910635
# 3  District  2917  1910635
# 4  District  2917  1910635

# %%
renamed_df = organized_df.rename(columns={"student_name":"Student Name",
                                                  "grade":"Grade",
                                                 "school_name": "School Name",
                                                 "reading_score": "Reading Score",
                                                 "math_score": "Math Score",
                                                  "type": "School Type",
                                                  "size": "School Size",
                                                  "budget": "School Budget"
                                                 })
renamed_df
# Out:
#             Student Name Grade         School Name  Reading Score  Math Score  \
# 0           Paul Bradley   9th   Huang High School             66          79
# 1           Victor Smith  12th   Huang High School             94          61
# 2        Kevin Rodriguez  12th   Huang High School             90          60
# 3      Dr. Richard Scott  12th   Huang High School             67          58
# 4             Bonnie Ray   9th   Huang High School             97          84
# ...                  ...   ...                 ...            ...         ...
# 39165       Donna Howard  12th  Thomas High School             99          90
# 39166          Dawn Bell  10th  Thomas High School             95          70
# 39167     Rebecca Tanner   9th  Thomas High School             73          84
# 39168       Desiree Kidd  10th  Thomas High School             99          90
# 39169    Carolyn Jackson  11th  Thomas High School             95          75
#
#       School Type  School Size  School Budget
# 0        District         2917        1910635
# 1        District         2917        1910635
# 2        District         2917        1910635
# 3        District         2917        1910635
# 4        District         2917        1910635
# ...           ...          ...            ...
# 39165     Charter         1635        1043130
# 39166     Charter         1635        1043130
# 39167     Charter         1635        1043130
# 39168     Charter         1635        1043130
# 39169     Charter         1635        1043130
#
# [39170 rows x 8 columns]

# %%
bins = [50, 60, 70, 80, 90, 100]
bin_labels = ['F', 'D', 'C', 'B', 'A']

# %%
index_by_school_df = renamed_df.set_index("School Name")
index_by_school_df
# Out:
#                          Student Name Grade  Reading Score  Math Score  \
# School Name
# Huang High School        Paul Bradley   9th             66          79
# Huang High School        Victor Smith  12th             94          61
# Huang High School     Kevin Rodriguez  12th             90          60
# Huang High School   Dr. Richard Scott  12th             67          58
# Huang High School          Bonnie Ray   9th             97          84
# ...                               ...   ...            ...         ...
# Thomas High School       Donna Howard  12th             99          90
# Thomas High School          Dawn Bell  10th             95          70
# Thomas High School     Rebecca Tanner   9th             73          84
# Thomas High School       Desiree Kidd  10th             99          90
# Thomas High School    Carolyn Jackson  11th             95          75
#
#                    School Type  School Size  School Budget
# School Name
# Huang High School     District         2917        1910635
# Huang High School     District         2917        1910635
# Huang High School     District         2917        1910635
# Huang High School     District         2917        1910635
# Huang High School     District         2917        1910635
# ...                        ...          ...            ...
# Thomas High School     Charter         1635        1043130
# Thomas High School     Charter         1635        1043130
# Thomas High School     Charter         1635        1043130
# Thomas High School     Charter         1635        1043130
# Thomas High School     Charter         1635        1043130
#
# [39170 rows x 7 columns]

# %%
index_by_school_df.columns
# Out:
# Index(['Student Name', 'Grade', 'Reading Score', 'Math Score', 'School Type',
#        'School Size', 'School Budget'],
#       dtype='object')

# %%
school_type = index_by_school_df['School Type'].unique()
school_type
# Out:
# array(['District', 'Charter'], dtype=object)

# %% [markdown]
# ## School Summary

# %%
#count total number of schools, students, budget
school_count = len(renamed_df["School Name"].unique())
school_count
# Out:
# 15

# %%
student_count = len(index_by_school_df["Student Name"].unique())
student_count
# Out:
# 32715

# %%
index_by_school_df.groupby(["School Name"]).agg({"Student Name": "count",
                                                   "School Budget": "median",
                                                   "Math Score": "mean",
                                                   "Reading Score": "mean"
    
                                                  }).reset_index()
# Out:
#               School Name  Student Name  School Budget  Math Score  \
# 0      Bailey High School          4976        3124928   77.048432
# 1     Cabrera High School          1858        1081356   83.061895
# 2    Figueroa High School          2949        1884411   76.711767
# 3        Ford High School          2739        1763916   77.102592
# 4     Griffin High School          1468         917500   83.351499
# 5   Hernandez High School          4635        3022020   77.289752
# 6      Holden High School           427         248087   83.803279
# 7       Huang High School          2917        1910635   76.629414
# 8     Johnson High School          4761        3094650   77.072464
# 9        Pena High School           962         585858   83.839917
# 10  Rodriguez High School          3999        2547363   76.842711
# 11    Shelton High School          1761        1056600   83.359455
# 12     Thomas High School          1635        1043130   83.418349
# 13     Wilson High School          2283        1319574   83.274201
# 14     Wright High School          1800        1049400   83.682222
#
#     Reading Score
# 0       81.033963
# 1       83.975780
# 2       81.158020
# 3       80.746258
# 4       83.816757
# 5       80.934412
# 6       83.814988
# 7       81.182722
# 8       80.966394
# 9       84.044699
# 10      80.744686
# 11      83.725724
# 12      83.848930
# 13      83.989488
# 14      83.955000

# %%
index_by_school_df['Sum of all Budgets'] = index_by_school_df.iloc[:, 3:].sum(axis=1)
budget_count = sum(index_by_school_df['Sum of all Budgets'])
budget_count
# Out:
# 83065975345

# %%
#Calculate the average math score, the average reading score, 
#the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
avg_math = index_by_school_df['Math Score'].mean()
avg_math
# Out:
# 78.98537145774827

# %%
avg_read = index_by_school_df['Reading Score'].mean()
avg_read
# Out:
# 81.87784018381414

# %%
passing_rate = (avg_math + avg_read)/2 
passing_rate
# Out:
# 80.43160582078121

# %%
#Calculate the percentage of students with a passing math score (70 or greater)
columns = ['Student Name', 'Grade',
       'Reading Score', 'Math Score', 'School Type', 'School Size', 'School Budget']
math_70_sorted_df = index_by_school_df.loc[index_by_school_df['Math Score'] >= 70, columns]
math_70_sorted_df.head()

new_student_count = len(math_70_sorted_df['Student Name'].unique())
new_student_count

new_M_percent = new_student_count/student_count
new_M_percent

index_by_school_df["% Passing Math"] = new_M_percent
index_by_school_df.head(10)
# Out:
#                         Student Name Grade  Reading Score  Math Score  \
# School Name
# Huang High School       Paul Bradley   9th             66          79
# Huang High School       Victor Smith  12th             94          61
# Huang High School    Kevin Rodriguez  12th             90          60
# Huang High School  Dr. Richard Scott  12th             67          58
# Huang High School         Bonnie Ray   9th             97          84
# Huang High School      Bryan Miranda   9th             94          94
# Huang High School      Sheena Carter  11th             82          80
# Huang High School       Nicole Baker  12th             96          69
# Huang High School       Michael Roth  10th             95          87
# Huang High School     Matthew Greene  10th             96          84
#
#                   School Type  School Size  School Budget  Sum of all Budgets  \
# School Name
# Huang High School    District         2917        1910635             1913631
# Huang High School    District         2917        1910635             1913613
# Huang High School    District         2917        1910635             1913612
# Huang High School    District         2917        1910635             1913610
# Huang High School    District         2917        1910635             1913636
# Huang High School    District         2917        1910635             1913646
# Huang High School    District         2917        1910635             1913632
# Huang High School    District         2917        1910635             1913621
# Huang High School    District         2917        1910635             1913639
# Huang High School    District         2917        1910635             1913636
#
#                    % Passing Math
# School Name
# Huang High School        0.777197
# Huang High School        0.777197
# Huang High School        0.777197
# Huang High School        0.777197
# Huang High School        0.777197
# Huang High School        0.777197
# Huang High School        0.777197
# Huang High School        0.777197
# Huang High School        0.777197
# Huang High School        0.777197

# %%
#Calculate the percentage of students with a passing reading score (70 or greater)
#Calculate the percentage of students with a passing math score (70 or greater)
columns = ['Student Name', 'Grade',
       'Reading Score', 'Math Score', 'School Type', 'School Size', 'School Budget']
read_70_sorted_df = index_by_school_df.loc[index_by_school_df['Reading Score'] >= 70, columns]
read_70_sorted_df.head()

new_student_Rcount = len(read_70_sorted_df['Student Name'].unique())
new_student_Rcount

new_R_percent = new_student_Rcount/student_count
new_R_percent

index_by_school_df["% Passing Reading"] = new_R_percent
index_by_school_df["Avg Passing Rate"] = passing_rate
index_by_school_df.head(10)
# Out:
#                         Student Name Grade  Reading Score  Math Score  \
# School Name
# Huang High School       Paul Bradley   9th             66          79
# Huang High School       Victor Smith  12th             94          61
# Huang High School    Kevin Rodriguez  12th             90          60
# Huang High School  Dr. Richard Scott  12th             67          58
# Huang High School         Bonnie Ray   9th             97          84
# Huang High School      Bryan Miranda   9th             94          94
# Huang High School      Sheena Carter  11th             82          80
# Huang High School       Nicole Baker  12th             96          69
# Huang High School       Michael Roth  10th             95          87
# Huang High School     Matthew Greene  10th             96          84
#
#                   School Type  School Size  School Budget  Sum of all Budgets  \
# School Name
# Huang High School    District         2917        1910635             1913631
# Huang High School    District         2917        1910635             1913613
# Huang High School    District         2917        1910635             1913612
# Huang High School    District         2917        1910635             1913610
# Huang High School    District         2917        1910635             1913636
# Huang High School    District         2917        1910635             1913646
# Huang High School    District         2917        1910635             1913632
# Huang High School    District         2917        1910635             1913621
# Huang High School    District         2917        1910635             1913639
# Huang High School    District         2917        1910635             1913636
#
#                    % Passing Math  % Passing Reading  Avg Passing Rate
# School Name
# Huang High School        0.777197           0.873819         80.431606
# Huang High School        0.777197           0.873819         80.431606
# Huang High School        0.777197           0.873819         80.431606
# Huang High School        0.777197           0.873819         80.431606
# Huang High School        0.777197           0.873819         80.431606
# Huang High School        0.777197           0.873819         80.431606
# Huang High School        0.777197           0.873819         80.431606
# Huang High School        0.777197           0.873819         80.431606
# Huang High School        0.777197           0.873819         80.431606
# Huang High School        0.777197           0.873819         80.431606

# %%
#format

# %%
summary_df = pd.DataFrame({"Total Schools": [school_count],
                              "Number of Students": student_count,
                              "Total Budget": budget_count,
                           "Average Math Score": avg_math,
                           "Average Reading Score": avg_read,
                           "Average Passing Rate": passing_rate,
                           "% Passing Math": new_M_percent,
                           "% Passing Reading": new_R_percent
                          })
summary_df
# Out:
#    Total Schools  Number of Students  Total Budget  Average Math Score  \
# 0             15               32715   83065975345           78.985371
#
#    Average Reading Score  Average Passing Rate  % Passing Math  \
# 0               81.87784             80.431606        0.777197
#
#    % Passing Reading
# 0           0.873819

# %%
# Create a list of the columns
columns = ['School Name', 'Student Name', 'Grade', 'Reading Score', 'Math Score', 'School Type',
       'School Size', 'School Budget']

#  Create a new df for "each school" with the columns. 
bailey_df = renamed_df.loc[renamed_df["School Name"] == "Bailey High School",  columns]
bailey_df.head()
# Out:
#               School Name         Student Name Grade  Reading Score  \
# 17871  Bailey High School         Blake Martin   9th             75
# 17872  Bailey High School         Kathryn Kane  12th             84
# 17873  Bailey High School         Richard Haas  11th             79
# 17874  Bailey High School          Frank Marsh   9th             71
# 17875  Bailey High School  Charles Goodman Jr.   9th             90
#
#        Math Score School Type  School Size  School Budget
# 17871          59    District         4976        3124928
# 17872          58    District         4976        3124928
# 17873          86    District         4976        3124928
# 17874          89    District         4976        3124928
# 17875          61    District         4976        3124928

# %%
index_by_school_df.groupby(["School Name"]).mean()
index_by_school_df
# Out:
#                          Student Name Grade  Reading Score  Math Score  \
# School Name
# Huang High School        Paul Bradley   9th             66          79
# Huang High School        Victor Smith  12th             94          61
# Huang High School     Kevin Rodriguez  12th             90          60
# Huang High School   Dr. Richard Scott  12th             67          58
# Huang High School          Bonnie Ray   9th             97          84
# ...                               ...   ...            ...         ...
# Thomas High School       Donna Howard  12th             99          90
# Thomas High School          Dawn Bell  10th             95          70
# Thomas High School     Rebecca Tanner   9th             73          84
# Thomas High School       Desiree Kidd  10th             99          90
# Thomas High School    Carolyn Jackson  11th             95          75
#
#                    School Type  School Size  School Budget  \
# School Name
# Huang High School     District         2917        1910635
# Huang High School     District         2917        1910635
# Huang High School     District         2917        1910635
# Huang High School     District         2917        1910635
# Huang High School     District         2917        1910635
# ...                        ...          ...            ...
# Thomas High School     Charter         1635        1043130
# Thomas High School     Charter         1635        1043130
# Thomas High School     Charter         1635        1043130
# Thomas High School     Charter         1635        1043130
# Thomas High School     Charter         1635        1043130
#
#                     Sum of all Budgets  % Passing Math  % Passing Reading  \
# School Name
# Huang High School              1913631        0.777197           0.873819
# Huang High School              1913613        0.777197           0.873819
# Huang High School              1913612        0.777197           0.873819
# Huang High School              1913610        0.777197           0.873819
# Huang High School              1913636        0.777197           0.873819
# ...                                ...             ...                ...
# Thomas High School             1044855        0.777197           0.873819
# Thomas High School             1044835        0.777197           0.873819
# Thomas High School             1044849        0.777197           0.873819
# Thomas High School             1044855        0.777197           0.873819
# Thomas High School             1044840        0.777197           0.873819
#
#                     Avg Passing Rate
# School Name
# Huang High School          80.431606
# Huang High School          80.431606
# Huang High School          80.431606
# Huang High School          80.431606
# Huang High School          80.431606
# ...                              ...
# Thomas High School         80.431606
# Thomas High School         80.431606
# Thomas High School         80.431606
# Thomas High School         80.431606
# Thomas High School         80.431606
#
# [39170 rows x 11 columns]

# %%
bailey_school_type = bailey_df['School Type']
bailey_school_type.head()
# Out:
# 17871    District
# 17872    District
# 17873    District
# 17874    District
# 17875    District
# Name: School Type, dtype: object

# %%
bailey_student_count = len(bailey_df['Student Name'].unique())
bailey_student_count
# Out:
# 4799

# %%
bailey_budget = bailey_df['School Budget']
bailey_budget.head()
# Out:
# 17871    3124928
# 17872    3124928
# 17873    3124928
# 17874    3124928
# 17875    3124928
# Name: School Budget, dtype: int64

# %%
bailey_per_stu_budget = (bailey_budget/bailey_student_count)
bailey_per_stu_budget.head()
# Out:
# 17871    651.162325
# 17872    651.162325
# 17873    651.162325
# 17874    651.162325
# 17875    651.162325
# Name: School Budget, dtype: float64

# %%
bailey_avg_math = bailey_df['Math Score'].mean()
bailey_avg_math
# Out:
# 77.04843247588424

# %%
bailey_avg_read = bailey_df['Reading Score'].mean()
bailey_avg_read
# Out:
# 81.03396302250803

# %%
columns = ['Student Name', 'Grade', 'School Name',
       'Reading Score', 'Math Score', 'School Type', 'School Size', 'School Budget']
B_math_70_sorted_df = bailey_df.loc[bailey_df['Math Score'] >= 70, columns]
B_math_70_sorted_df.head(10)

B_new_student_count = len(B_math_70_sorted_df['Student Name'].unique())
B_new_student_count

B_new_M_percent = B_new_student_count/bailey_student_count
B_new_M_percent
# Out:
# 0.6722233798708064

# %%
columns = ['Student Name', 'Grade', 'School Name',
       'Reading Score', 'Math Score', 'School Type', 'School Size', 'School Budget']
B_read_70_sorted_df = bailey_df.loc[bailey_df['Reading Score'] >= 70, columns]
B_read_70_sorted_df.head(10)

B_new_student_count = len(B_read_70_sorted_df['Student Name'].unique())
B_new_student_count

B_new_R_percent = B_new_student_count/bailey_student_count
B_new_R_percent
# Out:
# 0.822463013127735

# %%
bailey_comb_pass = (bailey_avg_read+bailey_avg_math)/2
bailey_comb_pass
# Out:
# 79.04119774919613

# %%
renamed_df["School Name"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'School Name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-809281ec495b> in <module>
# ----> 1 index_by_school_df["School Name"].value_counts()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'School Name'

# %%
school_summary_dict = [{"School Name ": [School Name],
                        "School Type": School Type,
                       "Number of Students": Student Count,
                        "Total Budget": School Budget,
                        "Average Math Score": bailey_avg_math,
                        "Average Reading Score": bailey_avg_read,
                        "Average Passing Rate": bailey_comb_pass
                        "% Passing Math": B_new_M_percent,
                        "% Passing Reading": B_new_R_percent
                       }]
                

school_sum_df = pd.DataFrame(school_summary_dict)
school_sum_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-b9644c69eda1> in <module>
#       5                            "Average Math Score": bailey_avg_math,
#       6                            "Average Reading Score": bailey_avg_read,
# ----> 7                            "Average Passing Rate": bailey_comb_pass
#       8                            #"% Passing Math": B_new_M_percent,
#       9                            #"% Passing Reading": B_new_R_percent
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      62     # figure out the index, if necessary
#      63     if index is None:
# ---> 64         index = extract_index(arrays)
#      65     else:
#      66         index = ensure_index(index)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     376                         f"length {len(index)}"
#     377                     )
# --> 378                     raise ValueError(msg)
#     379             else:
#     380                 index = ibase.default_index(lengths[0])
#
# ValueError: array length 1 does not match index length 4976

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)
#
# * Create a dataframe to hold the above results

# %% [markdown]
# ## Top Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the top five schools in overall passing rate

# %% [markdown]
# ## Bottom Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the five worst-performing schools

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
school_summary_df []

for row in df['year']:
    # Add 1 to the row and append it to next_year
    next_year.append(row + 1)

# Create df.next_year
df['next_year'] = next_year

# View the dataframe
df

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Sample bins. Feel free to create your own bins.
spending_bins = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"]

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Sample bins. Feel free to create your own bins.
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type.
